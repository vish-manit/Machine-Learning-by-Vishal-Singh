# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount', 
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']
df = df[cols_to_use]
df.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
# 3  Abbotsford      3    h     PI  Biggin  Northern Metropolitan
# 4  Abbotsford      4    h     VB  Nelson  Northern Metropolitan
#
#    Propertycount  Distance CouncilArea  Bedroom2  Bathroom  Car  Landsize  \
# 0         4019.0       2.5       Yarra       2.0       1.0  1.0     202.0
# 1         4019.0       2.5       Yarra       2.0       1.0  0.0     156.0
# 2         4019.0       2.5       Yarra       3.0       2.0  0.0     134.0
# 3         4019.0       2.5       Yarra       3.0       2.0  1.0      94.0
# 4         4019.0       2.5       Yarra       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price
# 0           NaN  1480000.0
# 1          79.0  1035000.0
# 2         150.0  1465000.0
# 3           NaN   850000.0
# 4         142.0  1600000.0

# %%
df.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          0
# Propertycount       0
# Distance            0
# CouncilArea      1369
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# Price               0
# dtype: int64

# %%
df.shape
# Out:
# (13580, 15)

# %%
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
# 3  Abbotsford      3    h     PI  Biggin  Northern Metropolitan
# 4  Abbotsford      4    h     VB  Nelson  Northern Metropolitan
#
#    Propertycount  Distance CouncilArea  Bedroom2  Bathroom  Car  Landsize  \
# 0         4019.0       2.5       Yarra       2.0       1.0  1.0     202.0
# 1         4019.0       2.5       Yarra       2.0       1.0  0.0     156.0
# 2         4019.0       2.5       Yarra       3.0       2.0  0.0     134.0
# 3         4019.0       2.5       Yarra       3.0       2.0  1.0      94.0
# 4         4019.0       2.5       Yarra       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price
# 0     151.96765  1480000.0
# 1      79.00000  1035000.0
# 2     150.00000  1465000.0
# 3     151.96765   850000.0
# 4     142.00000  1600000.0

# %%
df.shape
# Out:
# (12211, 15)

# %%
df.drop(['Suburb', 'Type', 'Method', 'SellerG', 'Regionname', 'CouncilArea'], axis = 'columns')
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0          2         4019.0       2.5       2.0       1.0  1.0     202.0
# 1          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 2          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 3          3         4019.0       2.5       3.0       2.0  1.0      94.0
# 4          4         4019.0       2.5       3.0       1.0  2.0     120.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 12208      3         6380.0       6.8       3.0       1.0  0.0     296.0
# 12209      2         4380.0       4.6       2.0       1.0  1.0       0.0
# 12210      3         2940.0      25.5       3.0       2.0  2.0     400.0
# 12211      2         6543.0       6.3       2.0       1.0  2.0     269.0
# 12212      6         6543.0       6.3       6.0       3.0  2.0    1087.0
#
#        BuildingArea      Price
# 0         151.96765  1480000.0
# 1          79.00000  1035000.0
# 2         150.00000  1465000.0
# 3         151.96765   850000.0
# 4         142.00000  1600000.0
# ...             ...        ...
# 12208     151.96765  1285000.0
# 12209      61.60000   560000.0
# 12210     151.96765   525300.0
# 12211     151.96765   750000.0
# 12212     388.50000  2450000.0
#
# [12211 rows x 9 columns]

# %%
df = pd.get_dummies(df)
df.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 1      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 2      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 3      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 4      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Abbotsford  ...  CouncilArea_Moreland  \
# 0     151.96765  1480000.0                  1  ...                     0
# 1      79.00000  1035000.0                  1  ...                     0
# 2     150.00000  1465000.0                  1  ...                     0
# 3     151.96765   850000.0                  1  ...                     0
# 4     142.00000  1600000.0                  1  ...                     0
#
#    CouncilArea_Nillumbik  CouncilArea_Port Phillip  CouncilArea_Stonnington  \
# 0                      0                         0                        0
# 1                      0                         0                        0
# 2                      0                         0                        0
# 3                      0                         0                        0
# 4                      0                         0                        0
#
#    CouncilArea_Unavailable  CouncilArea_Whitehorse  CouncilArea_Whittlesea  \
# 0                        0                       0                       0
# 1                        0                       0                       0
# 2                        0                       0                       0
# 3                        0                       0                       0
# 4                        0                       0                       0
#
#    CouncilArea_Wyndham  CouncilArea_Yarra  CouncilArea_Yarra Ranges
# 0                    0                  1                         0
# 1                    0                  1                         0
# 2                    0                  1                         0
# 3                    0                  1                         0
# 4                    0                  1                         0
#
# [5 rows x 619 columns]

# %%
X = df.drop(['Price'], axis = 'columns')
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(train_X, train_y)

# %%
reg.score(train_X, train_y)
# Out:
# 0.7127594917566731

# %%
reg.score(test_X, test_y)
# Out:
# -49737708790.3959

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso(alpha = 50, max_iter = 100, tol = 0.1)
lasso_reg.fit(train_X, train_y)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(test_X, test_y)
# Out:
# 0.6526668677329848

# %%
lasso_reg.score(train_X, train_y)
# Out:
# 0.7087458572177908

# %%
from sklearn import linear_model
ridge_reg = linear_model.Ridge(alpha = 50, max_iter = 100, tol = 0.1)
ridge_reg.fit(train_X, train_y)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(test_X, test_y)
# Out:
# 0.6506834554417511

# %%
ridge_reg.score(train_X, train_y)
# Out:
# 0.6796056728853327
